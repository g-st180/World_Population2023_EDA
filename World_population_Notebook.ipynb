# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df=pd.read_csv('countries-table.csv')

# %%
df.head(20)
# Out:
#           country  rank        area  landAreaKm cca2 cca3  netChange  \
# 0           India     1   3287590.0   2973190.0   IN  IND     0.4184
# 1           China     2   9706961.0   9424702.9   CN  CHN    -0.0113
# 2   United States     3   9372610.0   9147420.0   US  USA     0.0581
# 3       Indonesia     4   1904569.0   1877519.0   ID  IDN     0.0727
# 4        Pakistan     5    881912.0    770880.0   PK  PAK     0.1495
# 5         Nigeria     6    923768.0    910770.0   NG  NGA     0.1680
# 6          Brazil     7   8515767.0   8358140.0   BR  BRA     0.0393
# 7      Bangladesh     8    147570.0    130170.0   BD  BGD     0.0557
# 8          Russia     9  17098242.0  16376870.0   RU  RUS    -0.0158
# 9          Mexico    10   1964375.0   1943950.0   MX  MEX     0.0299
# 10       Ethiopia    11   1104300.0   1128571.3   ET  ETH     0.1008
# 11          Japan    12    377930.0    364500.0   JP  JPN    -0.0209
# 12    Philippines    13    342353.0    298170.0   PH  PHL     0.0561
# ...

# %%
df.shape
# Out:
# (234, 19)

# %%
pd.set_option('display.max_columns',25)

# %% [markdown]
# # Data Cleaning

# %%
df.columns=df.columns.str.title()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Country          234 non-null    object
#  1   Rank             234 non-null    int64
#  2   Area             234 non-null    float64
#  3   Landareakm       234 non-null    float64
#  4   Cca2             233 non-null    object
#  5   Cca3             234 non-null    object
#  6   Netchange        226 non-null    float64
#  7   Growthrate       234 non-null    float64
#  8   Worldpercentage  228 non-null    float64
#  9   Density          234 non-null    float64
#  10  Densitymi        234 non-null    float64
#  11  Place            234 non-null    int64
#  12  Pop1980          234 non-null    int64
#  13  Pop2000          234 non-null    int64
#  14  Pop2010          234 non-null    int64
#  15  Pop2022          234 non-null    int64
# ...

# %%
df.isnull().sum()
# Out:
# Country            0
# Rank               0
# Area               0
# Landareakm         0
# Cca2               1
# Cca3               0
# Netchange          8
# Growthrate         0
# Worldpercentage    6
# Density            0
# Densitymi          0
# Place              0
# Pop1980            0
# Pop2000            0
# Pop2010            0
# Pop2022            0
# Pop2023            0
# Pop2030            0
# Pop2050            0
# dtype: int64

# %%
df[df['Worldpercentage'].isnull()]
# Out:
#                        Country  Rank      Area  Landareakm Cca2 Cca3  \
# 228  Saint Pierre and Miquelon   229    242.00      242.00   PM  SPM
# 229                 Montserrat   230    102.00      102.00   MS  MSR
# 230           Falkland Islands   231  12173.00    12173.00   FK  FLK
# 231                       Niue   232    261.00      261.00   NU  NIU
# 232                    Tokelau   233     12.00       10.00   TK  TKL
# 233               Vatican City   234      0.44        0.44   VA  VAT
#
#      Netchange  Growthrate  Worldpercentage    Density  Densitymi  Place  \
# 228        NaN     -0.0038              NaN    24.1322    62.5025    666
# 229        NaN     -0.0009              NaN    43.0000   111.3700    500
# 230        NaN      0.0029              NaN     0.3114     0.8066    238
# 231        0.0      0.0005              NaN     7.4138    19.2017    570
# 232        NaN      0.0118              NaN   189.3000   490.2870    772
# ...

# %%
df.tail(15)
# Out:
#                        Country  Rank      Area  Landareakm Cca2 Cca3  \
# 219               Saint Martin   220     53.00       50.00   MF  MAF
# 220     British Virgin Islands   221    151.00      150.00   VG  VGB
# 221                      Palau   222    459.00      460.00   PW  PLW
# 222               Cook Islands   223    240.00      240.00   CK  COK
# 223                   Anguilla   224     91.00       91.00   AI  AIA
# 224                      Nauru   225     21.00       20.00   NR  NRU
# 225          Wallis and Futuna   226    274.00      274.00   WF  WLF
# 226                     Tuvalu   227     26.00       30.00   TV  TUV
# 227           Saint Barthelemy   228     21.00       25.00   BL  BLM
# 228  Saint Pierre and Miquelon   229    242.00      242.00   PM  SPM
# 229                 Montserrat   230    102.00      102.00   MS  MSR
# 230           Falkland Islands   231  12173.00    12173.00   FK  FLK
# 231                       Niue   232    261.00      261.00   NU  NIU
# ...

# %% [markdown]
# # All these countries have near to 0 contribution in world population

# %%
df.fillna(0,inplace=True)

# %%
df.isnull().sum()
# Out:
# Country            0
# Rank               0
# Area               0
# Landareakm         0
# Cca2               0
# Cca3               0
# Netchange          0
# Growthrate         0
# Worldpercentage    0
# Density            0
# Densitymi          0
# Place              0
# Pop1980            0
# Pop2000            0
# Pop2010            0
# Pop2022            0
# Pop2023            0
# Pop2030            0
# Pop2050            0
# dtype: int64

# %%
df
# Out:
#               Country  Rank        Area  Landareakm Cca2 Cca3  Netchange  \
# 0               India     1  3287590.00  2973190.00   IN  IND     0.4184
# 1               China     2  9706961.00  9424702.90   CN  CHN    -0.0113
# 2       United States     3  9372610.00  9147420.00   US  USA     0.0581
# 3           Indonesia     4  1904569.00  1877519.00   ID  IDN     0.0727
# 4            Pakistan     5   881912.00   770880.00   PK  PAK     0.1495
# ..                ...   ...         ...         ...  ...  ...        ...
# 229        Montserrat   230      102.00      102.00   MS  MSR     0.0000
# 230  Falkland Islands   231    12173.00    12173.00   FK  FLK     0.0000
# 231              Niue   232      261.00      261.00   NU  NIU     0.0000
# 232           Tokelau   233       12.00       10.00   TK  TKL     0.0000
# 233      Vatican City   234        0.44        0.44   VA  VAT     0.0000
#
#      Growthrate  Worldpercentage    Density  Densitymi  Place    Pop1980  \
# ...

# %%
filtr=df['Growthrate']>-0.04
df.loc[filtr]
# Out:
#               Country  Rank        Area  Landareakm Cca2 Cca3  Netchange  \
# 0               India     1  3287590.00  2973190.00   IN  IND     0.4184
# 1               China     2  9706961.00  9424702.90   CN  CHN    -0.0113
# 2       United States     3  9372610.00  9147420.00   US  USA     0.0581
# 3           Indonesia     4  1904569.00  1877519.00   ID  IDN     0.0727
# 4            Pakistan     5   881912.00   770880.00   PK  PAK     0.1495
# ..                ...   ...         ...         ...  ...  ...        ...
# 229        Montserrat   230      102.00      102.00   MS  MSR     0.0000
# 230  Falkland Islands   231    12173.00    12173.00   FK  FLK     0.0000
# 231              Niue   232      261.00      261.00   NU  NIU     0.0000
# 232           Tokelau   233       12.00       10.00   TK  TKL     0.0000
# 233      Vatican City   234        0.44        0.44   VA  VAT     0.0000
#
#      Growthrate  Worldpercentage    Density  Densitymi  Place    Pop1980  \
# ...

# %%
#df.loc[filtr,'Growthrate'].plot(kind='hist',bins=15,edgecolor='black')
sns.histplot(df.loc[filtr,'Growthrate'],bins=15,kde=True,alpha=.7)
# Out:
# <AxesSubplot:xlabel='Growthrate', ylabel='Count'>

# %%
df
# Out:
#               Country  Rank        Area  Landareakm Cca2 Cca3  Netchange  \
# 0               India     1  3287590.00  2973190.00   IN  IND     0.4184
# 1               China     2  9706961.00  9424702.90   CN  CHN    -0.0113
# 2       United States     3  9372610.00  9147420.00   US  USA     0.0581
# 3           Indonesia     4  1904569.00  1877519.00   ID  IDN     0.0727
# 4            Pakistan     5   881912.00   770880.00   PK  PAK     0.1495
# ..                ...   ...         ...         ...  ...  ...        ...
# 229        Montserrat   230      102.00      102.00   MS  MSR     0.0000
# 230  Falkland Islands   231    12173.00    12173.00   FK  FLK     0.0000
# 231              Niue   232      261.00      261.00   NU  NIU     0.0000
# 232           Tokelau   233       12.00       10.00   TK  TKL     0.0000
# 233      Vatican City   234        0.44        0.44   VA  VAT     0.0000
#
#      Growthrate  Worldpercentage    Density  Densitymi  Place    Pop1980  \
# ...

# %%
df['Worldpercentage']=df['Worldpercentage']*100
df
# Out:
#               Country  Rank        Area  Landareakm Cca2 Cca3  Netchange  \
# 0               India     1  3287590.00  2973190.00   IN  IND     0.4184
# 1               China     2  9706961.00  9424702.90   CN  CHN    -0.0113
# 2       United States     3  9372610.00  9147420.00   US  USA     0.0581
# 3           Indonesia     4  1904569.00  1877519.00   ID  IDN     0.0727
# 4            Pakistan     5   881912.00   770880.00   PK  PAK     0.1495
# ..                ...   ...         ...         ...  ...  ...        ...
# 229        Montserrat   230      102.00      102.00   MS  MSR     0.0000
# 230  Falkland Islands   231    12173.00    12173.00   FK  FLK     0.0000
# 231              Niue   232      261.00      261.00   NU  NIU     0.0000
# 232           Tokelau   233       12.00       10.00   TK  TKL     0.0000
# 233      Vatican City   234        0.44        0.44   VA  VAT     0.0000
#
#      Growthrate  Worldpercentage    Density  Densitymi  Place    Pop1980  \
# ...

# %%
df.sort_values(by='Density',ascending=False).head(20)
# Out:
#           Country  Rank       Area  Landareakm Cca2 Cca3  Netchange  \
# 166         Macau   167      32.90       32.90   MO  MAC     0.0003
# 216        Monaco   217       2.02        2.00   MC  MCO     0.0000
# 113     Singapore   114     710.00      718.00   SG  SGP     0.0012
# 103     Hong Kong   104    1104.00     1050.00   HK  HKG     0.0002
# 218     Gibraltar   219       6.80        6.80   GI  GIB     0.0000
# 153       Bahrain   154     765.00      785.00   BH  BHR     0.0004
# 173      Maldives   174     300.00      300.00   MV  MDV    -0.0001
# 172         Malta   173     316.00      320.00   MT  MLT     0.0001
# 7      Bangladesh     8  147570.00   130170.00   BD  BGD     0.0557
# 212  Sint Maarten   213      34.00       34.00   SX  SXM     0.0000
# 205       Bermuda   206      54.00       54.00   BM  BMU     0.0000
# 233  Vatican City   234       0.44        0.44   VA  VAT     0.0000
# 206      Guernsey   207      78.00       63.00   GG  GGY     0.0000
# ...

# %% [markdown]
# # Bangladesh is the most dense nation in world
# # Taiwan has a great contribution in world percentage if compared to its density

# %%
df.plot(kind='scatter',x='Landareakm',y='Worldpercentage',figsize=(8,5),marker='x',color='Green')
plt.xscale('log')
plt.yscale('log')
plt.show()

# %%
df['Growthrate'].min(), df['Growthrate'].max()
# Out:
# (-0.0745, 0.0498)

# %%
import json

# %% [markdown]
# #

# %%
fig=px.choropleth(df, 
                  locations='Country',
                  locationmode='country names',
                  hover_name='Country',
                  color='Growthrate',
                 color_continuous_scale=px.colors.diverging.BrBG,
                 color_continuous_midpoint=0)

fig.show()
# Out:
# <div>                            <div id="c8a20779-7c8e-483f-9807-8647aceaa2e4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c8a20779-7c8e-483f-9807-8647aceaa2e4")) {                    Plotly.newPlot(                        "c8a20779-7c8e-483f-9807-8647aceaa2e4",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>Country=%{location}<br>Growthrate=%{z}<extra></extra>","hovertext":["India","China","United States","Indonesia","Pakistan","Nigeria","Brazil","Bangladesh","Russia","Mexico","Ethiopia","Japan","Philippines","Egypt","DR Congo","Vietnam","Iran","Turkey","Germany","Thailand","United Kingdom","Tanzania","France","South Africa","Italy","Kenya","Myanmar","Colombia","South Korea","Uganda","S
# ...

# %%
df.set_index('Country',inplace=True)

# %%
df['Worldpercentage']=df['Worldpercentage']*100

# %%
filtr=df['Worldpercentage']>2
df.loc[filtr]
# Out:
#                Rank       Area  Landareakm  Netchange  Growthrate  \
# Country
# India             1  3287590.0   2973190.0     0.4184      0.0081
# China             2  9706961.0   9424702.9    -0.0113     -0.0002
# United States     3  9372610.0   9147420.0     0.0581      0.0050
# Indonesia         4  1904569.0   1877519.0     0.0727      0.0074
# Pakistan          5   881912.0    770880.0     0.1495      0.0198
# Nigeria           6   923768.0    910770.0     0.1680      0.0241
# Brazil            7  8515767.0   8358140.0     0.0393      0.0052
# Bangladesh        8   147570.0    130170.0     0.0557      0.0103
#
#                Worldpercentage    Density  Densitymi  Place    Pop1980  \
# Country
# India                    17.85   480.5033  1244.5036    356  696828385
# China                    17.81   151.2696   391.7884    156  982372466
# United States             4.25    37.1686    96.2666    840  223140018
# ...

# %%
df['Growthrate'].nlargest(10)
# Out:
# Country
# Syria       0.0498
# Moldova     0.0498
# Niger       0.0380
# DR Congo    0.0329
# Chad        0.0313
# Mali        0.0310
# Somalia     0.0310
# Angola      0.0308
# Mayotte     0.0303
# Tanzania    0.0296
# Name: Growthrate, dtype: float64

# %%
df.set_index('Country',inplace=True)

# %%
df.iloc[0,10:].plot(kind='line',figsize=(12,8),marker='o')
df.iloc[1,10:].plot(kind='line',figsize=(12,8),marker='o')
df.iloc[2,10:].plot(kind='line',figsize=(12,8),marker='o')
df.iloc[3,10:].plot(kind='line',figsize=(12,8),marker='o')

plt.legend()
plt.show()
